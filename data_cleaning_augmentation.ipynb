# %%
import numpy as np
import pandas as pd
import torch
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
from format_data import *

# %% [markdown]
# # Nettoyage des données (retrait des doublons et NA)

# %%
data = pd.read_csv("./data/train.csv")
data = data.drop(columns=["SNo"])
data = data.drop_duplicates()
duplicate_mask = data.drop(columns="Label").duplicated(keep=False)
data = data[~duplicate_mask].reset_index(drop=True)
data = data.rename(columns={"lat": "LAT", 'lon': "LON"})
data
# Out:
#              LAT       LON        TMQ       U850       V850       UBOT  \
# 0      21.707953  275.0000  78.909431 -58.805229  36.200672 -58.260475
# 1      21.473272  275.0000  80.641357 -42.340290  58.060246 -56.400234
# 2      21.707953  275.3125  76.891205 -45.996342  42.691631 -48.993065
# 3      21.473272  275.3125  76.771362 -33.228142  57.195755 -46.387169
# 4      21.707953  275.6250  74.268501 -37.684723  42.142948 -41.747562
# ...          ...       ...        ...        ...        ...        ...
# 18300 -24.524120  241.5625  30.094780  25.473230   1.147071  23.153421
# 18301  13.259452  253.4375  65.683533  23.562666 -15.100705  24.040194
# 18302  13.259452  253.7500  68.822723  28.599319  -8.304391  25.647541
# 18303  13.494133  253.4375  68.789070  19.561129 -26.216906  25.676321
# 18304  13.494133  253.7500  73.321968  21.677361 -22.360260  27.409748
#
#             VBOT    QREFHT            PS           PSL        T200  \
# ...

# %% [markdown]
# # Transformation des données avant le génération de données artificielle

# %% [markdown]
# ### Clustering sur les emplacements par latitude et longitude

# %%
import hdbscan
import pandas as pd
import numpy as np

def cluster_data(df):
    # Define a cluster selection epsilon to group points within this distance.
    # In this case, it's 10 meters (0.01 km divided by the radius of the Earth).
    eps = 400 / 6378

    # Initiate HDBSCAN clusterer
    clusterer = hdbscan.HDBSCAN(min_cluster_size=100,
                                metric='haversine',
                                cluster_selection_epsilon=eps)

    # Convert coordinates to radians for distance-based grouping and cluster them
    clusterer.fit(np.radians(df[['LAT', 'LON']]).values)

    # Return the cluster labels for each point
    return clusterer.labels_
    

def plot_clusters(df, labels):
    # Create a scatter plot
    plt.scatter(df['LON'], df['LAT'], c=labels, cmap='rainbow', s=50)
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')
    plt.title('HDBSCAN Clustering')
    plt.colorbar()
    plt.show()

# %%
labels = cluster_data(data)
data["LOCATION"] = labels
plot_clusters(data, labels)

# %% [markdown]
# On peut voir dans le tableau ci-dessous que les latitude pour les "LOCATION" inférieure à 2 sont négatives, alors que pour les "LOCATION" supérieure à 2 elles sont positives. Cela est utilisé dans notre fichier *format_data.py* afin de créer l'attribut "SOUTHERN_HEMISPHERE".

# %%
location_coordinate_relation = data[["LOCATION", "LAT", "LON"]].drop_duplicates().groupby("LOCATION").mean()
location_coordinate_relation
# Out:
#                 LAT         LON
# LOCATION
# 0        -30.743155  353.750000
# 1        -20.886571  229.687500
# 2        -24.641460  241.875000
# 3         22.998696  276.666667
# 4         13.142112  253.125000
# 5         22.059974  244.375000

# %% [markdown]
# Le dictionnaire de coordonées est utiliser afin d'obtenir des labels constants entre les différents jeu de données. En effet, le clustering pourrait avoir un résultat différent pour le jeu de données test

# %%
# UTILE POUR OBTENIR LES LOCATIONS SUR LE JEU TEST
location_dict = data.groupby('LOCATION').apply(lambda x: list(set((lat, lon) for lat, lon in zip(x['LAT'], x['LON'])))).to_dict()
location_dict
# Out:
# {0: [(-31.09517601, 353.75),
#   (-31.09517601, 353.4375),
#   (-31.09517601, 353.125),
#   (-30.62581486, 353.125),
#   (-30.62581486, 353.4375),
#   (-30.62581486, 353.75),
#   (-30.86049544, 354.0625),
#   (-30.86049544, 354.375),
#   (-30.39113429, 354.375),
#   (-30.39113429, 354.0625),
#   (-30.86049544, 353.75),
#   (-30.86049544, 353.4375),
#   (-30.86049544, 353.125),
#   (-30.39113429, 353.125),
#   (-30.39113429, 353.4375),
#   (-30.39113429, 353.75),
#   (-31.09517601, 354.375),
#   (-31.09517601, 354.0625),
#   (-30.62581486, 354.375),
#   (-30.62581486, 354.0625)],
#  1: [(-21.00391134, 229.6875),
#   (-21.00391134, 229.375),
#   (-21.00391134, 229.0625),
#   (-20.5345502, 229.6875),
#   (-20.5345502, 229.375),
#   (-20.5345502, 229.0625),
#   (-21.23859192, 230.3125),
#   (-21.23859192, 230.0),
#   (-20.76923077, 230.0),
#   (-20.76923077, 230.3125),
#   (-21.23859192, 229.375),
#   (-21.23859192, 229.6875),
#   (-21.23859192, 229.0625),
#   (-20.76923077, 229.375),
# ...

# %% [markdown]
# ### Extraction du mois de "time"

# %%
data['MONTH'] = data['time'].apply(lambda x: int(str(x)[4:6]))
data = data.drop(columns=["time", "LAT", "LON"])

# %% [markdown]
# ### Transformation de l'échelle de mesure de PRECT de (m/s) à (mm/h)

# %%
data["PRECT"] = data["PRECT"].apply(lambda x: 0 if x < 0 else x)
data["PRECT"] = np.sqrt(data["PRECT"] * 10_000_000_000)

# %% [markdown]
# # Génération de nouvelles données pour les classes sous représentées

# %%
data_label0 = data[data['Label'] == 0]
data_label1 = data[data['Label'] == 1]
data_label2 = data[data['Label'] == 2]

# %%
from ctgan import CTGAN

# Define the number of synthetic samples needed
synthetic_samples_needed_1 = 3 * data_label1.shape[0]
synthetic_samples_needed_2 = data_label2.shape[0]

discrete_columns = [
    'LOCATION',
    'MONTH',
    'Label'
]

# %%
# Initialize and train CTGAN for label 1
ctgan_1 = CTGAN(epochs=10000, verbose=True, cuda=True)  # Reduced epochs for time efficiency
ctgan_1.fit(data_label1, discrete_columns)
synthetic_1 = ctgan_1.sample(synthetic_samples_needed_1)
# Out:
# Gen. (-0.29) | Discrim. (-0.42): 100%|██████████| 10000/10000 [13:42<00:00, 12.16it/s]

# %%
# Initialize and train CTGAN for label 2
ctgan_2 = CTGAN(epochs=4000, verbose=True, cuda=True)  # Reduced epochs for time efficiency
ctgan_2.fit(data_label2, discrete_columns)
synthetic_2 = ctgan_2.sample(synthetic_samples_needed_2)
# Out:
# Gen. (-0.56) | Discrim. (-0.06): 100%|██████████| 4000/4000 [26:27<00:00,  2.52it/s]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')

# Assume 'data', 'data_label1', and 'synthetic_1' are defined somewhere above this code
# Define colors and labels
colors = {
    "Real Data": 'blue',
    "Synthetic Data": 'orange',
    # Add more categories and colors if needed
}

# Determine the grid layout
n_features = len(data.columns.drop('Label'))
n_cols = 2
# Ensure that we have two equal subplots, if there's an odd number of features, add an additional subplot for symmetry
n_rows = 5

fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 4 * n_rows))
axes = axes.flatten()  # Flatten the axes array

# Loop through each feature and plot the real and synthetic data distributions
for i, feature in enumerate(data.columns.drop('Label')[0:9]):
    ax = axes[i]
    if feature in ["MONTH", "LOCATION"]:
        # Plot histogram of proportions for Real Data
        sns.histplot(data_label1[feature], kde=False, alpha=0.3, color=colors["Real Data"], ax=ax, label="Real Data", stat="density")
        # Plot histogram of proportions for Synthetic Data
        sns.histplot(synthetic_1[feature], kde=False, alpha=0.4, color=colors["Synthetic Data"], ax=ax, label="Synthetic Data", stat="density")
    else:
        # Plot KDE for Real Data
        sns.kdeplot(data_label1[feature], label="Real Data", shade=True, color=colors["Real Data"], ax=ax)
        # Plot KDE for Synthetic Data
        sns.kdeplot(synthetic_1[feature], label="Synthetic Data", shade=True, color=colors["Synthetic Data"], ax=ax)

    ax.set_title(f"Proportional Distribution of {feature}")
    ax.legend()

# If there is an odd number of subplots, remove the last one(s)
if len(axes) > n_features:
    for j in range(n_features, len(axes)):
        fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')

# Assume 'data', 'data_label1', and 'synthetic_1' are defined somewhere above this code
# Define colors and labels
colors = {
    "Real Data": 'blue',
    "Synthetic Data": 'orange',
    # Add more categories and colors if needed
}

# Determine the grid layout
n_features = len(data.columns.drop('Label'))
n_cols = 2
# Ensure that we have two equal subplots, if there's an odd number of features, add an additional subplot for symmetry
n_rows = 5

fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 4 * n_rows))
axes = axes.flatten()  # Flatten the axes array

# Loop through each feature and plot the real and synthetic data distributions
for i, feature in enumerate(data.columns.drop('Label')[9:]):
    ax = axes[i]
    if feature in ["MONTH", "LOCATION"]:
        # Plot histogram of proportions for Real Data
        sns.histplot(data_label1[feature], kde=False, alpha=0.3, color=colors["Real Data"], ax=ax, label="Real Data", stat="density")
        # Plot histogram of proportions for Synthetic Data
        sns.histplot(synthetic_1[feature], kde=False, alpha=0.4, color=colors["Synthetic Data"], ax=ax, label="Synthetic Data", stat="density")
    else:
        # Plot KDE for Real Data
        sns.kdeplot(data_label1[feature], label="Real Data", shade=True, color=colors["Real Data"], ax=ax)
        # Plot KDE for Synthetic Data
        sns.kdeplot(synthetic_1[feature], label="Synthetic Data", shade=True, color=colors["Synthetic Data"], ax=ax)

    ax.set_title(f"Proportional Distribution of {feature}")
    ax.legend()

# If there is an odd number of subplots, remove the last one(s)
if len(axes) > n_features:
    for j in range(n_features, len(axes)):
        fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

warnings.filterwarnings('ignore')

# Define colors and labels
colors = {
    "Real Data": 'blue',
    "Synthetic Data": 'orange',
    # Add more categories and colors if needed
}

# Determine the grid layout
n_features = len(data.columns.drop('Label'))
n_cols = 2
# Ensure that we have two equal subplots, if there's an odd number of features, add an additional subplot for symmetry
n_rows = 5

fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 4 * n_rows))
axes = axes.flatten()  # Flatten the axes array

# Loop through each feature and plot the real and synthetic data distributions
for i, feature in enumerate(data.columns.drop('Label')[0:9]):
    ax = axes[i]
    if feature in ["MONTH", "LOCATION"]:
        # Plot histogram of proportions for Real Data
        sns.histplot(data_label2[feature], kde=False, alpha=0.3, color=colors["Real Data"], ax=ax, label="Real Data", stat="density")
        # Plot histogram of proportions for Synthetic Data
        sns.histplot(synthetic_2[feature], kde=False, alpha=0.4, color=colors["Synthetic Data"], ax=ax, label="Synthetic Data", stat="density")
    else:
        # Plot KDE for Real Data
        sns.kdeplot(data_label2[feature], label="Real Data", shade=True, color=colors["Real Data"], ax=ax)
        # Plot KDE for Synthetic Data
        sns.kdeplot(synthetic_2[feature], label="Synthetic Data", shade=True, color=colors["Synthetic Data"], ax=ax)

    ax.set_title(f"Proportional Distribution of {feature}")
    ax.legend()

# If there are odd numbers of features, remove the extra subplot
if n_features % n_cols:
    fig.delaxes(axes[-1])

# Adjust layout
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

warnings.filterwarnings('ignore')

# Define colors and labels
colors = {
    "Real Data": 'blue',
    "Synthetic Data": 'orange',
    # Add more categories and colors if needed
}

# Determine the grid layout
n_features = len(data.columns.drop('Label'))
n_cols = 2
# Ensure that we have two equal subplots, if there's an odd number of features, add an additional subplot for symmetry
n_rows = 5

fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 4 * n_rows))
axes = axes.flatten()  # Flatten the axes array

# Loop through each feature and plot the real and synthetic data distributions
for i, feature in enumerate(data.columns.drop('Label')[9:]):
    ax = axes[i]
    if feature in ["MONTH", "LOCATION"]:
        # Plot histogram of proportions for Real Data
        sns.histplot(data_label2[feature], kde=False, alpha=0.3, color=colors["Real Data"], ax=ax, label="Real Data", stat="density")
        # Plot histogram of proportions for Synthetic Data
        sns.histplot(synthetic_2[feature], kde=False, alpha=0.4, color=colors["Synthetic Data"], ax=ax, label="Synthetic Data", stat="density")
    else:
        # Plot KDE for Real Data
        sns.kdeplot(data_label2[feature], label="Real Data", shade=True, color=colors["Real Data"], ax=ax)
        # Plot KDE for Synthetic Data
        sns.kdeplot(synthetic_2[feature], label="Synthetic Data", shade=True, color=colors["Synthetic Data"], ax=ax)

    ax.set_title(f"Proportional Distribution of {feature}")
    ax.legend()

# If there are odd numbers of features, remove the extra subplot
if n_features % n_cols:
    fig.delaxes(axes[-1])

# Adjust layout
plt.tight_layout()
plt.show()

# %%
synthetic_1["MONTH"].describe()
# Out:
# count    1593.000000
# mean        8.023227
# std         1.428827
# min         6.000000
# 25%         7.000000
# 50%         8.000000
# 75%         9.000000
# max        10.000000
# Name: MONTH, dtype: float64

# %%
data = pd.concat([data_label0, data_label1, data_label2, synthetic_1, synthetic_2])
data = data.sample(frac=1).reset_index(drop=True)
data
# Out:
#              TMQ       U850      V850       UBOT      VBOT    QREFHT  \
# 0      23.537859  -1.520899  0.857227  -0.839581 -3.492708  0.010385
# 1      56.441036  -3.735136  5.890765  -8.839947  2.193805  0.020002
# 2      29.220510  26.035845 -2.774979  22.453836 -5.601638  0.012403
# 3      34.224255  -4.189527 -7.287977  -5.575746 -5.585425  0.015289
# 4      56.246055  -5.341722  0.095705  -5.531648  1.616406  0.020010
# ...          ...        ...       ...        ...       ...       ...
# 22395  44.290741   4.925665  4.044641   5.528638  8.026493  0.017983
# 22396  51.020018   0.752961  7.229506  -7.696564  7.961772  0.017543
# 22397  34.216710   0.963712  2.874027 -12.380035  2.988569  0.013158
# 22398  17.751591   0.197293  0.351031   6.442270  5.374423  0.011424
# 22399  48.259556  -0.296365  0.348966  -1.023565 -1.087880  0.018380
#
#                   PS            PSL        T200        T500      PRECT  \
# ...

# %% [markdown]
# # Sauvegarde

# %%
data.to_csv("./data/GAN_train.csv")
